# %%
#ici nous allons analyser les données d'une base de données pour en tirer des conclusions 
# création des environnements virtuels pour pouvoir gérer chaque projet de manière indépendante


""" 
exemple
creation d'un environnement virtuel

    python -m venv dataAnalyse 
    cd .\dataAnalyse\
        cd .\Scripts\
            .\activate : activer l'environnement virtuel pour le projet 
"""
import pandas  as pd
import numpy as np
